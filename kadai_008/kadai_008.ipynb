# %%
import random
ver = random.randint(0, 100)
print("変数の値",ver)
if ver % 15 == 0:
      print("FizzBuzz")
elif ver % 3 == 0:
      print("Fizz")
elif ver % 5 == 0:
      print("Buzz")
else:
      print(ver)
# Out:
# 変数の値 21
# Fizz
