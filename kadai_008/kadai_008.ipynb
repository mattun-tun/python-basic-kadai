# %%
import random
var = random.randint(0, 100)
print("変数の値",var)
if var % 15 == 0:
      print("FizzBuzz")
elif var % 3 == 0:
      print("Fizz")
elif var % 5 == 0:
      print("Buzz")
else:
      print(var)
# Out:
# 変数の値 35
# Buzz
