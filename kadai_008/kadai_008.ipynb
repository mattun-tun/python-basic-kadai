# %%
import random
ber = random.randint(0, 100)
print("変数の値",ber)
if ber % 15 == 0:
      print("FizzBuzz")
elif ber % 3 == 0:
      print("Fizz")
elif ber % 5 == 0:
      print("Buzz")
else:
      print(ber)
# Out:
# 変数の値 57
# Fizz
