# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def printinfo(self,name, age):
    self.name = name
    self.age = age
human = Human("太郎",36)
print(human.name)
print(human.age)
# Out:
# 太郎
# 36
